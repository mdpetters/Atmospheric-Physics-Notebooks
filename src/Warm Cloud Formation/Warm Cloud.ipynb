# %% [markdown]
#  # <center> MEA 412: Warm Cloud Microphysics </center>
#
# ## Background (Review from MEA 312):
#
# When parcels of air ascend adiabatically, both temperature and dew-point temperature decrease. As a result, relative humidity increases. When the relative humidity is 100%, the parcel has reached its <i> lifted condensation level </i> (LCL). Ascend beyond the LCL results in condensation and a cloud forms. The temperature profile above the LCL follows the <i> saturated adiabatic lapse rate </i> (SALR). The <i> adiabatic liquid water mixing ratio </i> is liquid water mixing ratio that condenses due to adiabatic lifting. The adiabatic liquid water mixing ratio is zero at cloud base and increases with height.
#
# <img src="figures/cloud_formation.png" width="500">
#
# <b> Figure 1.</b> Schematic diagram of the steps involved in cloud formation. </b> <br>
#
# - Adiabatic ascent leads to a decrease in temperature and dewpoint temperature and an increase in saturation ratio.
#
# - The lifting condensation level (LCL) is the thermodynamic cloud base and corresponds to the atmospheric pressure level where the saturation ratio $S$=1.
#
# - The height of the LCL is proportional to the dewpoint depression.
#
# - The saturated adiabatic lapse rate (SALR) is the change in temperature and dewpoint temperature with height for adiabatic expansion above the LCL.
#
# - Adiabatic cloud liquid water mixing ratio is zero at cloud base and increases with height above cloud base.
#
#
# <b> Questions to be answered in this Lecture</b>
# 1. Clouds (and rain) are a dispersion of droplets. What is the number concentration of droplets inside the cloud?
# 2. What is the average diameter of cloud droplets?
#
# <b> Motivation:</b>
# The number concentration and mean droplet size determines the albedo of the cloud, and how readily the cloud precipitates. We therefore seek to understand the mechanism that determines these quantities.
#
#  <img src="figures/cloud1.gif" width="300">  <img src="figures/cloud2.jpg" width="300">
#
# <b> Figure 2.</b> Top: Shallow marine cumulus with low droplet number concentration and large drop diameter: fuzzy and precipitating, Bottom: Continental cumulus with high droplet number concentration and small drop diameter: sharp edges/no rain. </b> <br>
#
# - The smaller droplets in continental clouds results in the boundaries of these clouds being well-defined, because the droplets evaporate quickly in the non-saturated ambient air
# - The absence of droplets much beyond the main boundary of continental cumulus clouds gives them a harder appearance
# - The larger droplets in marine clouds lead to the release of precipitation in shallower clouds, and with smaller updrafts, than in continental clouds
# - The larger number of droplets makes continental clouds brighter than marine clouds, resulting in more reflection back to space.

# %%
using Interact
T0 = widget(["0", "5", "10", "15", "20"]; value = "10")
display(T0)
observe(T0)
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-3340959154347198086\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-2143167805361179615\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n            console.log(\"Jupyter WebIO nbextension detected; not loading ad-hoc.\");\n            hide();\n            return;\n        }\n    } else if (window.location.pathname.includes(\"/lab\")) {\n        // Guessing JupyterLa\n        console.log(\"Jupyter Lab detected; make sure the @webio/jupyter-lab-provider labextension is installed.\");\n        hide();\n        return;\n    }\n})();\n\n</script>\n<p\n    id=\"webio-warning-3340959154347198086\"\n    class=\"output_text output_stderr\"\n    style=\"padding: 1em; font-weight: bold;\"\n>\n    Unable to load WebIO. Please make sure WebIO works for your Jupyter client.\n    For troubleshooting, please see <a href=\"https://juliagizmos.github.io/WebIO.jl/latest/providers/ijulia/\">\n    the WebIO/IJulia documentation</a>.\n    <!-- TODO: link to installation docs. -->\n</p>\n")
# (div { className="interact-widget" }
#     (div { attributes="data-bind" => "foreach : options_js" className="buttons has-addons is-centered" }
#     (span { attributes=Dict("data-bind"=>"click: function (){\$root.update(val)}, css: {'is-primary is-selected' : \$root.index() == val, 'interact-widget is-medium button ' : true}") }
#       (label { attributes=Dict("data-bind"=>"text : key") }))))
# Observable{Any} with 1 listeners. Value:
# "10"

# %%
include("scripts/Cloud formation figure 1.jl")
# Out:
# Observable{Any} with 0 listeners. Value:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:cx,Int64},Measures.Length{:cy,Int64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0cx, 0cy), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.6666666666666666w, 0.0h), (0.3333333333333333w, 1.0h)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Add{Measures.Add{Measures.Length{:w,Float64},Measures.Length{:mm,Float64}},Measures.Length{:mm,Float64}},Measures.Add{Measures.Add{Measures.Length{:h,Float64},Measures.Length{:mm,Float64}},Measures.Length{:mm,Float64}}}}((5.0mm, 5.0mm), (1.0w + -5.0mm + -5.0mm, 1.0h + -5.0mm + -5.0mm)), nothing, nothing, nothing, nothing, List([Compose.Table(Array{Compose.Context,1}[[] [] [Context(T,fsz,fnt,f,s)] []; [Context(AdhocContainerPromise), Context(AdhocContainerPromise)] [Context(AdhocContainerPromise)] [Context(Context(Context(Context(Context(Context(L,svgc(color_zLCL),sd,s),lw,f,svgc(geometry))),Context(Context(Context(L,svgc(color_wl),sd,s),lw,f,svgc(geometry))),svgc(plotpanel))),Context(Context(Context(T,svgc(text_box),f),fo,svgc(guide crosshair)),Context(Context(Context(R,f),Context(T,f,fsz,fnt),svgc(text_box)),fo,svgc(guide helpscreen)),Context(Context(T,jsc,svgc(text_box),f),fo,svgc(guide questionmark))),Context(Context(Context(L,jsc,jsc,svga,svgc(guide ygridlines xfixed),sd,lw,s,v),Context(L,svgc(guide ygridlines xfixed),sd,lw,s)),Context(Context(L,jsc,jsc,svga,svgc(guide xgridlines yfixed),sd,lw,s,v),Context(L,svgc(guide xgridlines yfixed),sd,lw,s)),Context(R,svga,f,s,svgc(guide background))),jsc)] [Context(AdhocContainerPromise), Context(AdhocContainerPromise)]; [] [] [Context(AdhocContainerPromise), Context(AdhocContainerPromise)] []; [] [] [Context(AdhocContainerPromise), Context(AdhocContainerPromise)] []], 3:3, 2:2, nothing, nothing, nothing, Any[], Compose.UnitBox{Int64,Int64,Int64,Int64}(0, 3, 2, -3, 2.0mm, 2.0mm, 2.0mm, 2.0mm), 0, false, false)]), List([]), List([Compose.Property{Compose.JSIncludePrimitive}(Compose.JSIncludePrimitive[JSIncludePrimitive("/home/mdpetter/.julia/packages/Gadfly/1wgcD/src/gadfly.js", ("Gadfly", "Gadfly"))]), Compose.Property{Compose.SVGClassPrimitive}(Compose.SVGClassPrimitive[SVGClassPrimitive("plotroot xscalable yscalable")])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol(""))]), List([]), List([]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.3333333333333333w, 0.0h), (0.3333333333333333w, 1.0h)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Add{Measures.Add{Measures.Length{:w,Float64},Measures.Length{:mm,Float64}},Measures.Length{:mm,Float64}},Measures.Add{Measures.Add{Measures.Length{:h,Float64},Measures.Length{:mm,Float64}},Measures.Length{:mm,Float64}}}}((5.0mm, 5.0mm), (1.0w + -5.0mm + -5.0mm, 1.0h + -5.0mm + -5.0mm)), nothing, nothing, nothing, nothing, List([Compose.Table(Array{Compose.Context,1}[[] [] [Context(T,fsz,fnt,f,s)] []; [Context(AdhocContainerPromise), Context(AdhocContainerPromise)] [Context(AdhocContainerPromise)] [Context(Context(Context(Context(Context(Context(L,svgc(color_zLCL),sd,s),lw,f,svgc(geometry))),Context(Context(Context(L,svgc(color_RH),sd,s),lw,f,svgc(geometry))),svgc(plotpanel))),Context(Context(Context(T,svgc(text_box),f),fo,svgc(guide crosshair)),Context(Context(Context(R,f),Context(T,f,fsz,fnt),svgc(text_box)),fo,svgc(guide helpscreen)),Context(Context(T,jsc,svgc(text_box),f),fo,svgc(guide questionmark))),Context(Context(Context(L,jsc ...
# "   Tdew-values             T-values"
# (div { style=Dict("display"=>"flex","flex-direction"=>"row") }
#   (div { style=Dict("padding"=>0.5em) }
#     Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Scope(Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :span), Any[Node{DOM}(DOM(:html, :label), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text : key")))], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"click: function (){\$root.update(val)}, css: {'is-primary is-selected' : \$root.index() == val, 'interact-widget is-medium button ' : true}")))], Dict{Symbol,Any}(:attributes=>("data-bind"=>"foreach : options_js"),:className=>"buttons has-addons is-centered")), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("options_js"=>(Observable{Any} with 1 listeners. Value:
# OrderedDict[OrderedDict{String,Any}("key"=>"-20","val"=>1,"id"=>"idF21v0KnL"), OrderedDict{String,Any}("key"=>"-15","val"=>2,"id"=>"idz5m7mZeP"), OrderedDict{String,Any}("key"=>"-10","val"=>3,"id"=>"ideALNNO8d"), OrderedDict{String,Any}("key"=>"-5","val"=>4,"id"=>"idsTOCAuBR"), OrderedDict{String,Any}("key"=>"0","val"=>5,"id"=>"idFPtpjIF1")], nothing),"index"=>(Observable{Any} with 2 listeners. Value:
# 5, nothing)), Set(String[]), nothing, Asset[Asset("js", "knockout", "/home/mdpetter/.julia/packages/Knockout/1sDlc/src/../assets/knockout.js"), Asset("js", "knockout_punches", "/home/mdpetter/.julia/packages/Knockout/1sDlc/src/../assets/knockout_punches.js"), Asset("js", nothing, "/home/mdpetter/.julia/packages/InteractBase/9mFwe/src/../assets/all.js"), Asset("css", nothing, "/home/mdpetter/.julia/packages/InteractBase/9mFwe/src/../assets/style.css"), Asset("css", nothing, "/home/mdpetter/.julia/packages/Interact/SbgIk/src/../assets/bulma_confined.min.css")], Dict{Any,Any}("options_js"=>Any[JSString("(function (val){return (val!=this.model[\"options_js\"]()) ? (this.valueFromJulia[\"options_js\"]=true, this.model[\"options_js\"](val)) : undefined})")],"index"=>Any[JSString("(function (val){return (val!=this.model[\"index\"]()) ? (this.valueFromJulia[\"index\"]=true, this.model[\"index\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:32,sz_curr:0), Set(AbstractConnection[]), Condition(Any[])), WebIO.JSString[JSString("function () {\n    var handler = (function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init: function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            });\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            });\n            ko.applyBindingsToNode(\n                element,\n                {\n                    value: stringified,\n                    valueUpdate: allBindings.get('valueUpdate'),\n                },\n                context,\n            );\n        }\n    };\n    var json_data = {\"options_js\":WebIO.getval({\"name\":\"options_js\",\"scope\":\"18145528913381877458\",\"id\":\"ob_17\",\"type\":\"observable\"}),\"index\":WebIO.getval({\"name\":\"index\",\"scope\":\"18145528913381877458\",\"id\":\"ob_16\",\"type\":\"observable\"})};\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        [this[\"update\"]=function (val) {this.index(val)}]\n        \n        [this[\"options_js\"].subscribe((function (val){!(this.valueFromJulia[\"options_js\"]) ? (WebIO.setval({\"name\":\"options_js\",\"scope\":\"18145528913381877458\",\"id\":\"ob_17\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"options_js\"]=false}),self),this[\"index\"].subscribe((function (val){!(this.valueFromJulia[\"index\"]) ? (WebIO.setval({\"name\":\"index\",\"scope\":\"18145528913381877458\",\"id\":\"ob_16\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"index\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n);\n    (WebIO.importBlock({\"data\":[{\"name\":\"knockout\",\"type\":\"js\",\"url\":\"/assetserver/1503158485b02e0968d9f832090f5cea0c910682-knockout.js\"},{\"name\":\"knockout_punches\",\"type\":\"js\",\"url\":\"/assetserver/f10960c7e21e75e0cf1443ef46b58960db6cb3e3-knockout_punches.js\"}],\"type\":\"async_block\"})).then((imports) => handler.apply(this, imports));\n}\n")])], Dict{Symbol,Any}(:className=>"interact-widget")))
#   (div { style=Dict("padding"=>0.5em) }
#     Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Scope(Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :span), Any[Node{DOM}(DOM(:html, :label), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text : key")))], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"click: function (){\$root.update(val)}, css: {'is-primary is-selected' : \$root.index() == val, 'interact-widget is-medium button ' : true}")))], Dict{Symbol,Any}(:attributes=>("data-bind"=>"foreach : options_js"),:className=>"buttons has-addons is-centered")), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("options_js"=>(Observable{Any} with 1 listeners. Value:
# OrderedDict[OrderedDict{String,Any}("key"=>"0","val"=>1,"id"=>"idpmxOldCU"), OrderedDict{String,Any}("key"=>"5","val"=>2,"id"=>"idEDV336jt"), OrderedDict{String,Any}("key"=>"10","val"=>3,"id"=>"idCO9bhKKx"), OrderedDict{String,Any}("key"=>"15","val"=>4,"id"=>"idyLlXOdsw"), OrderedDict{String,Any}("key"=>"20","val"=>5,"id"=>"idD3Clsch6")], nothing),"index"=>(Observable{Any} with 2 listeners. Value:
# 3, nothing)), Set(String[]), nothing, Asset[Asset("js", "knockout", "/home/mdpetter/.julia/packages/Knockout/1sDlc/src/../assets/knockout.js"), Asset("js", "knockout_punches", "/home/mdpetter/.julia/packages/Knockout/1sDlc/src/../assets/knockout_punches.js"), Asset("js", nothing, "/home/mdpetter/.julia/packages/InteractBase/9mFwe/src/../assets/all.js"), Asset("css", nothing, "/home/mdpetter/.julia/packages/InteractBase/9mFwe/src/../assets/style.css"), Asset("css", nothing, "/home/mdpetter/.julia/packages/Interact/SbgIk/src/../assets/bulma_confined.min.css")], Dict{Any,Any}("options_js"=>Any[JSString("(function (val){return (val!=this.model[\"options_js\"]()) ? (this.valueFromJulia[\"options_js\"]=true, this.model[\"options_js\"](val)) : undefined})")],"index"=>Any[JSString("(function (val){return (val!=this.model[\"index\"]()) ? (this.valueFromJulia[\"index\"]=true, this.model[\"index\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:32,sz_curr:0), Set(AbstractConnection[]), Condition(Any[])), WebIO.JSString[JSString("function () {\n    var handler = (function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init: function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            });\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            });\n            ko.applyBindingsToNode(\n                element,\n                {\n                    value: stringified,\n                    valueUpdate: allBindings.get('valueUpdate'),\n                },\n                context,\n            );\n        }\n    };\n    var json_data = {\"options_js\":WebIO.getval({\"name\":\"options_js\",\"scope\":\"11696198481037058980\",\"id\":\"ob_12\",\"type\":\"observable\"}),\"index\":WebIO.getval({\"name\":\"index\",\"scope\":\"11696198481037058980\",\"id\":\"ob_11\",\"type\":\"observable\"})};\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        [this[\"update\"]=function (val) {this.index(val)}]\n        \n        [this[\"options_js\"].subscribe((function (val){!(this.valueFromJulia[\"options_js\"]) ? (WebIO.setval({\"name\":\"options_js\",\"scope\":\"11696198481037058980\",\"id\":\"ob_12\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"options_js\"]=false}),self),this[\"index\"].subscribe((function (val){!(this.valueFromJulia[\"index\"]) ? (WebIO.setval({\"name\":\"index\",\"scope\":\"11696198481037058980\",\"id\":\"ob_11\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"index\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n);\n    (WebIO.importBlock({\"data\":[{\"name\":\"knockout\",\"type\":\"js\",\"url\":\"/assetserver/1503158485b02e0968d9f832090f5cea0c910682-knockout.js\"},{\"name\":\"knockout_punches\",\"type\":\"js\",\"url\":\"/assetserver/f10960c7e21e75e0cf1443ef46b58960db6cb3e3-knockout_punches.js\"}],\"type\":\"async_block\"})).then((imports) => handler.apply(this, imports));\n}\n")])], Dict{Symbol,Any}(:className=>"interact-widget"))))

# %% [markdown]
# ## <font color='red'> A. Exercises (use the slider to explore) </font>
# 1. How does the difference between the surface temperature and dew-point temperature (a.k.a dew-point depression) influence the height of the LCL?
# 2. How does the surface dew-point depression relate to the relative humidity at the surface?
# 3. Why is the temperature and dew-point temperature identical above the LCL?
# 4. Why does relative humidity increase with height below the LCL?
# 5. Why is the relative humidity constant above the LCL?
# 6. Why is the liquid water mixing ratio zero below the LCL?
# 7. Why does the liquid water mixing ratio increase with height above the LCL?
# 8. List the factors that go into the calculation of the liquid water mixing ratio. Then rank them by importance.
